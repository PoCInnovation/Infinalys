# %% [markdown]
# # Init

# %% [markdown]
# ## Imports

# %%
import sys, os

import tensorflow as tf

import numpy as np

import requests

import matplotlib

# Specify the backend of matplotlib to display graphs (here tkinter backend)
matplotlib.use("TkAgg")

from matplotlib import pyplot as plt

# Used to display matplotlib inside jupyter notebook
# %matplotlib inline


# Disable tensorflow update warning
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %% [markdown]
# ## Declare Global Consts

# %%
API_KEY  = 'A0P959H21M0HZXUB'
LOOKBACK = 24
PREDICT  = 2

# %% [markdown]
# # Create dataset

# %% [markdown]
# ## Fetch data

# %%
def fetch_data(stock):
    r = requests.get(f'https://www.alphavantage.co/query?function=TIME_SERIES_MONTHLY&symbol={stock}&apikey={API_KEY}&datatype=csv')
    return r.text.split('\r\n')

dataset = fetch_data('AAPL')

# %%
def format_data(dataset):
    tab = []
    for line in dataset:
        tab.append(line.split(','))
    for line in tab[1:]:
        for i in range(len(line)):
            if i == 0:
                line[i] = len(tab) - tab.index(line) - 1
            line[i] = float(line[i])    
    labels = tab[0]
    tab = list(reversed(tab[1:]))
    tab = tab[1:] # Remove last line which is empty
    return labels, tab    

labels, dataset = format_data(dataset)

# %% [markdown]
# ## Visualize dataset

# %%
def visualize_data(labels, dataset):
    plt.table(cellText=dataset,
          colWidths = [0.25]*len(dataset[0]),
          colLabels=labels,
          cellLoc = 'center', rowLoc = 'center',
          loc='top')

visualize_data(labels, dataset)

# %%
def plot_data(dataset):
    data_open = [data[1] for data in dataset]
    data_high = [data[2] for data in dataset]
    data_low = [data[3] for data in dataset]
    data_close = [data[4] for data in dataset]
    data_time = [data[0] for data in dataset]
    plt.plot(data_time , data_open)
    plt.plot(data_time , data_close)
    plt.plot(data_time , data_high)
    plt.plot(data_time , data_low)
    plt.title('Stock evolution')
    plt.ylabel('stock')
    plt.xlabel('month')
    plt.legend(['open', 'close', 'high', 'low'], loc='upper left')
    plt.show()

plot_data(dataset)

# %% [markdown]
# ## Normalize data

# %%
def normalize_data(dataset):
    dataset = np.swapaxes(dataset,0,1)
    for i in range(len(dataset)):
        dataset[i] = (dataset[i] - min(dataset[i])) / (max(dataset[i]) - min(dataset[i]))
    dataset = np.swapaxes(dataset, 0, 1)
    return dataset

dataset = normalize_data(dataset)

# %% [markdown]
# ## Split dataset

# %%
def split_dataset(dataset):
    x, y = [], []
    for i in range(LOOKBACK, len(dataset)):
        x.append(dataset[i-LOOKBACK:i,1:5])
        y.append(dataset[i-LOOKBACK:i,-1])
    return np.array(x), np.array(y)

x_train, y_train = split_dataset(dataset)
y_train = np.expand_dims(y_train,2)
print(x_train.shape, y_train.shape)
# Out:
# (216, 24, 4) (216, 24, 1)

# %% [markdown]
# # AI

# %% [markdown]
# ## Define model

# %%
def define_model():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.LSTM(4, input_shape=(LOOKBACK, 4), return_sequences=True))
    model.add(tf.keras.layers.Dropout(0.5))
    model.add(tf.keras.layers.Dense(1, activation='relu'))
    return model

model = define_model()

# %% [markdown]
# ## Compile model

# %%
def compile_model(model):
    model.compile(optimizer='adam',loss='mse')
    return model

model = compile_model(model)

# %% [markdown]
# ## Train AI

# %%
def train_ai(model, x_train, y_train):
    model.fit(x_train, y_train, epochs=150, batch_size=27)
    
train_ai(model, x_train, y_train)
# Out:
# Epoch 1/150
# 216/216 [==============================] - 7s 34ms/sample - loss: 0.0714
# Epoch 2/150
# 216/216 [==============================] - 0s 546us/sample - loss: 0.0662
# Epoch 3/150
# 216/216 [==============================] - 0s 631us/sample - loss: 0.0615
# Epoch 4/150
# 216/216 [==============================] - 0s 652us/sample - loss: 0.0568
# Epoch 5/150
# 216/216 [==============================] - 0s 577us/sample - loss: 0.0527
# Epoch 6/150
# 216/216 [==============================] - 0s 592us/sample - loss: 0.0490
# Epoch 7/150
# 216/216 [==============================] - 0s 576us/sample - loss: 0.0467
# Epoch 8/150
# 216/216 [==============================] - 0s 592us/sample - loss: 0.0429
# Epoch 9/150
# 216/216 [==============================] - 0s 646us/sample - loss: 0.0406
# Epoch 10/150
# 216/216 [==============================] - 0s 634us/sample - loss: 0.0382
# Epoch 11/150
# 216/216 [==============================] - 0s 658us/sample - loss: 0.0365
# Epoch 12/150
# 216/216 [==============================] - 0s 592us/sample - loss: 0.0350
# Epoch 13/150
# 216/216 [==============================] - 0s 592us/sample - loss: 0.0329
# Epoch 14/150
# 216/216 [==============================] - 0s 570us/sample - loss: 0.0315
# Epoch 15/150
# 216/216 [==============================] - 0s 562us/sample - loss: 0.0309
# Epoch 16/150
# 216/216 [==============================] - 0s 589us/sample - loss: 0.0293s - loss: 0.028
# Epoch 17/150
# 216/216 [==============================] - 0s 591us/sample - loss: 0.0292
# Epoch 18/150
# 216/216 [==============================] - 0s 568us/sample - loss: 0.0286
# Epoch 19/150
# 216/216 [==============================] - 0s 613us/sample - loss: 0.0280
# Epoch 20/150
# 216/216 [==============================] - 0s 616us/sample - loss: 0.0273
# Epoch 21/150
# 216/216 [==============================] - 0s 597us/sample - loss: 0.0272
# Epoch 22/150
# 216/216 [==============================] - 0s 567us/sample - loss: 0.0272
# Epoch 23/150
# 216/216 [==============================] - 0s 609us/sample - loss: 0.0269
# Epoch 24/150
# 216/216 [==============================] - 0s 623us/sample - loss: 0.0267
# Epoch 25/150
# 216/216 [==============================] - 0s 605us/sample - loss: 0.0259
# Epoch 26/150
# 216/216 [==============================] - 0s 569us/sample - loss: 0.0263
# Epoch 27/150
# 216/216 [==============================] - 0s 568us/sample - loss: 0.0259
# Epoch 28/150
# 216/216 [==============================] - 0s 604us/sample - loss: 0.0257
# Epoch 29/150
# 216/216 [==============================] - 0s 617us/sample - loss: 0.0255
# Epoch 30/150
# 216/216 [==============================] - 0s 627us/sample - loss: 0.0253
# Epoch 31/150
# 216/216 [==============================] - 0s 594us/sample - loss: 0.0253
# Epoch 32/150
# 216/216 [==============================] - 0s 593us/sample - loss: 0.0253
# Epoch 33/150
# 216/216 [==============================] - 0s 635us/sample - loss: 0.0248
# Epoch 34/150
# 216/216 [==============================] - 0s 603us/sample - loss: 0.0251
# Epoch 35/150
# 216/216 [==============================] - 0s 586us/sample - loss: 0.0250
# Epoch 36/150
# 216/216 [==============================] - 0s 602us/sample - loss: 0.0243
# Epoch 37/150
# 216/216 [==============================] - 0s 617us/sample - loss: 0.0245
# Epoch 38/150
# 216/216 [==============================] - 0s 593us/sample - loss: 0.0239
# 216/216 [==============================] - 0s 566us/sample - loss: 0.0210
# Epoch 79/150
# 216/216 [==============================] - 0s 598us/sample - loss: 0.0206
# Epoch 80/150
# 216/216 [==============================] - 0s 627us/sample - loss: 0.0209
# Epoch 81/150
# 216/216 [==============================] - 0s 592us/sample - loss: 0.0206
# Epoch 82/150
# 216/216 [==============================] - 0s 568us/sample - loss: 0.0205
# Epoch 83/150
# 216/216 [==============================] - 0s 584us/sample - loss: 0.0204
# Epoch 84/150
# 216/216 [==============================] - 0s 634us/sample - loss: 0.0204
# Epoch 85/150
# 216/216 [==============================] - 0s 718us/sample - loss: 0.0198
# Epoch 86/150
# 216/216 [==============================] - 0s 748us/sample - loss: 0.0201
# Epoch 87/150
# 216/216 [==============================] - 0s 837us/sample - loss: 0.0200
# Epoch 88/150
# 216/216 [==============================] - 0s 952us/sample - loss: 0.0200
# Epoch 89/150
# 216/216 [==============================] - 0s 966us/sample - loss: 0.0199
# Epoch 90/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0198
# Epoch 91/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0198
# Epoch 92/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0195
# Epoch 93/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0199
# Epoch 94/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0193
# Epoch 95/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0193
# Epoch 96/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0195
# Epoch 97/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0192
# Epoch 98/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0190
# Epoch 99/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0192
# Epoch 100/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0189
# Epoch 101/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0190
# Epoch 102/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0188
# Epoch 103/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0191
# Epoch 104/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0187
# Epoch 105/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0187
# Epoch 106/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0186
# Epoch 107/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0185
# Epoch 108/150
# 216/216 [==============================] - 0s 854us/sample - loss: 0.0184
# Epoch 109/150
# 216/216 [==============================] - 0s 810us/sample - loss: 0.0185
# Epoch 110/150
# 216/216 [==============================] - 0s 933us/sample - loss: 0.0186
# Epoch 111/150
# 216/216 [==============================] - 0s 944us/sample - loss: 0.0185
# Epoch 112/150
# 216/216 [==============================] - 0s 927us/sample - loss: 0.0182
# Epoch 113/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0183
# Epoch 114/150
# 216/216 [==============================] - 0s 992us/sample - loss: 0.0181
# Epoch 115/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0185
# Epoch 116/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0183
# Epoch 117/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0180
# Epoch 118/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0182
# Epoch 119/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0179
# Epoch 120/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0182
# Epoch 121/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0181
# Epoch 122/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0179
# Epoch 123/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0182
# Epoch 124/150
# 216/216 [==============================] - 0s 988us/sample - loss: 0.0177
# Epoch 125/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0183
# Epoch 126/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0180
# Epoch 127/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0181
# Epoch 128/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0179
# Epoch 129/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0178
# Epoch 130/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0181
# Epoch 131/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0176
# Epoch 132/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0177
# Epoch 133/150
# 216/216 [==============================] - 0s 994us/sample - loss: 0.0179
# Epoch 134/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0176
# Epoch 135/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0176
# Epoch 136/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0177
# Epoch 137/150
# 216/216 [==============================] - 0s 973us/sample - loss: 0.0174
# Epoch 138/150
# 216/216 [==============================] - 0s 951us/sample - loss: 0.0176
# Epoch 139/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0173
# Epoch 140/150
# 216/216 [==============================] - 0s 972us/sample - loss: 0.0177
# Epoch 141/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0174
# Epoch 142/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0177
# Epoch 143/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0174
# Epoch 144/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0176
# Epoch 145/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0174
# Epoch 146/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0174
# Epoch 147/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0173
# Epoch 148/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0175
# Epoch 149/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0174
# Epoch 150/150
# 216/216 [==============================] - 0s 1ms/sample - loss: 0.0172
